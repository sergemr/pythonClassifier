# %%
from google.colab import data_table
import pandas as pd
data_table.enable_dataframe_formatter()
import pandas as pd
from google.colab import drive

# %%
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
drive.mount('/content/gdrive') 
path = f'/content/gdrive/My Drive/TrabajoMaster/TrabajoTFM' 

path2=f'{path}/invoicesCSV.csv'

print(path2)
invoices = pd.read_csv(path2, sep=";") 

invoices.head(5)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/TrabajoMaster/TrabajoTFM/invoicesCSV.csv
#             first_name      last_name                      email  product_id  \
# 0         Carmen Nixon  Todd Anderson  marvinjackson@example.com         133
# 1  Mrs. Heather Miller    Julia Moore      jeffrey84@example.net         155
# 2          Crystal May   Philip Moody       ugoodman@example.com         151
# 3          Bobby Weber     Mark Scott       ssanchez@example.com         143
# 4        Kristen Welch    David David      cynthia66@example.net         168
#
#    qty amount invoice_date                          address            city  \
# 0    9  14,57      10/9/82                 283 Wendy Common  West Alexander
# 1    5  65,48      3/10/12  13567 Patricia Circles Apt. 751     Andreamouth
# 2    9  24,66      23/3/76     6389 Debbie Island Suite 470         Coxbury
# ...

# %%
#invoices['amount'] = invoices['amount'].apply(lambda x: float(x.split()[0].replace(',', '.')))
 
print("invoices",invoices.dtypes)
#invoices['amount'] = invoices['amount'].replace(',', '').astype(float)
#invoices.dtypes
#sns.boxplot(x=invoices['amount'])
# Out:
# invoices first_name       object
# last_name        object
# email            object
# product_id        int64
# qty               int64
# amount          float64
# invoice_date     object
# address          object
# city             object
# stock_code        int64
# job              object
# customer_id       int64
# corporate_id      int64
# doc_type        float64
# description      object
# items            object
# revenue         float64
# dtype: object

# %%
sns.boxplot(x=invoices['amount'])
